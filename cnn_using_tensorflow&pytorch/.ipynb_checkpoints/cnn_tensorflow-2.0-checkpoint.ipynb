# %%
import os
import tarfile
import urllib.request as url
import numpy as np
import tensorflow as tf

# %% [markdown]
# # download cifar
# check if CIFAR in directory, if not, download

# %%
def download_data():
    if not os.path.exists('.././data'):
        os.mkdir('.././data')
    if not os.path.exists('.././data/cifar-10-python.tar.gz'):
        print("CIFAR-10 not found, downloading...")
        url.urlretrieve("https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz",
                        ".././data/cifar-10-python.tar.gz")
        print("done")
        print("Download completed!")
    else:
        print('CIFAR-10 already exists.')
        
# download_data()

# %%
import glob
import _pickle as pickle
def load_data():
    if not os.path.exists('.././data/cifar-10-python.tar.gz'):
        download_data()
    if not os.path.exists('.././data/cifar-10-batches-py/'):
        print("extracting...")
        package = tarfile.open('.././data/cifar-10-python.tar.gz')
        package.extractall('.././data')
        package.close()
        
    root_dir = os.getcwd()
    os.chdir('.././data/cifar-10-batches-py')
    train_data = []
    train_label = []
    test_data = []
    test_label = []
    data_train = glob.glob('data_batch*')
    print(data_train)
    #try:
    for name in data_train:
        handle = open(name, 'rb')
        cmap = pickle.load(handle, encoding='bytes')
        train_data.append(cmap[b'data'])
        train_label.append(cmap[b'labels'])
        handle.close()
    # Turn the dataset into numpy compatible arrays.
    train_data = np.concatenate(train_data, axis=0)
    train_label = np.concatenate(train_label)
    handle = open('test_batch', 'rb')
    cmap = pickle.load(handle, encoding='bytes')
    test_data.append(cmap[b'data'])
    test_label.append(cmap[b'labels'])
    test_data = np.array(test_data[0])
    test_label = np.array(test_label[0])
    #except BaseException:
#         os.chdir(root_dir)
#         print('Something went wrong...')
#         return None
    os.chdir(root_dir)
    return train_data,train_label,test_data,test_label

train_data,train_label,test_data,test_label = load_data()
val_size = 1000
val_data = train_data[-1000:]
val_label = train_label[-1000:]
train_data = train_data[:-1000]
train_label = train_label [:-1000]
print(train_data.shape, train_label.shape)
print(val_data.shape, val_label.shape)
print(test_data.shape, test_label.shape)
# Out:
# ['data_batch_1', 'data_batch_4', 'data_batch_3', 'data_batch_2', 'data_batch_5']
# (49000, 3072) (49000,)
# (1000, 3072) (1000,)
# (10000, 3072) (10000,)

# %% [markdown]
# # build neural network using tensorflow

# %%
import tensorflow as tf
def cnn_4_cifar(features, labels, mode = tf.estimator.ModeKeys.TRAIN):
    # features aka. x, labels aka y, i don't know mode right now
#     train_x = features
#     train_y = labels
#     input_data = tf.placeholder(
#         dtype = tf.float32,
#         shape = [None, 3072],
#         name = "input")
    
#     labels = tf.placeholder(
#         dtype = tf.int32,
#         shape = [None, ],
#         name = "labels")
    
    input_data = features["x"]
    
   
    
    ###### normalize layer ######
    normal_layer = input_data/255.
    
#     normal_layer = tf.layers.batch_normalization(
#         inputs = input_data,
#         training= mode == tf.estimator.ModeKeys.TRAIN,
#         reuse=None,
#         name = 'batch_normal'
#     )
    

    #normalize_layer = tf.nn.l2_normalize()
    
    input_labels = tf.one_hot(indices=labels,
                        depth = 10,
                        name='one_hot_label',
                        axis=1,
                       dtype = tf.int32)
    
    ###### input layer ######
    
    reshape_layer = tf.reshape(normal_layer, [-1, 32, 32, 3])
    reshape_layer = tf.cast(reshape_layer, dtype = tf.float32)
    
    
    ###### convolutional layer #1 ######
    
    conv1 = tf.layers.conv2d(
        inputs = reshape_layer,
        filters = 16,
        kernel_size = [5,5],
        padding = "valid",
        activation = tf.nn.relu
    )
    
    ###### pooling layer #1 ######
    
    pool1 = tf.layers.max_pooling2d(
        inputs=conv1, pool_size = [2,2], strides = 2)
    
    ###### lrn layer #1 #####
    
    lrn1 = tf.nn.local_response_normalization(
        pool1,
        depth_radius = 5
)
    
    ###### convolutional layer #2 ######
        
    conv2 = tf.layers.conv2d(
        inputs = lrn1,
        filters = 64,
        kernel_size = [5,5],
        padding = "valid",
        activation = tf.nn.relu
    )
    
    ###### lrn layer #2 #####
    
    lrn2 = tf.nn.local_response_normalization(
        conv2,
        depth_radius = 5
    )
    
    ###### pooling layer #2 ######
    
    pool2 = tf.layers.max_pooling2d(
        inputs = lrn2,
        pool_size = [2,2],
        strides = 2)
    
    conv3 = tf.layers.conv2d(
        inputs = pool2,
        filters = 32,
        kernel_size = [1,1],
        padding = "valid",
        activation = tf.nn.relu
    )

    
    ###### flat layer ######
    
    pool_flat = tf.reshape(conv3, [-1, 5 * 5 * 32])
    
    ###### dense layer ######
    
    dense1 = tf.layers.dense(
        inputs = pool_flat,                     
        units = 230,                     
        activation = tf.nn.relu
    )
    
    dense_normal1 = tf.layers.batch_normalization(dense1)
    
    dense2 = tf.layers.dense(
        inputs = dense_normal1,                     
        units = 42,                     
        activation = tf.nn.relu
    )
    
    dense3 = tf.layers.dense(
        inputs = dense1,                     
        units = 80,                     
        activation = tf.nn.relu
    )
    
    ###### dropout layer ######
    
    dropout = tf.layers.dropout(
        inputs = dense3,
        rate = 0.1,
        training = (mode == tf.estimator.ModeKeys.TRAIN)
    )
    ###### logits layer ######
    
    logits = tf.layers.dense(inputs=dropout, units=10)
    
    ###### prediction ######
    
    predictions = {
        "class" : tf.argmax(input = logits, axis = 1),
        "prob" : tf.nn.softmax(
            logits, 
            name = "softmax_tensor")
    }
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(
            mode=mode, 
            predictions = predictions)
    
    ###### loss ######
    
    loss = tf.losses.sparse_softmax_cross_entropy(
        labels = labels,
        logits = logits
    )
    
    ##### train op ######
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.train.RMSPropOptimizer(
            learning_rate = 0.0002
        )
#         optimizer = tf.train.GradientDescentOptimizer(
#             learning_rate = 0.01
#         )
        train_op = optimizer.minimize(
            loss = loss,
            global_step = tf.train.get_global_step()
        )
        return tf.estimator.EstimatorSpec(
            mode = mode,
            loss = loss,
            train_op = train_op
            )
    
    ##### eval op ######
    
    if mode == tf.estimator.ModeKeys.EVAL:
        eval_metric_ops = {
            "accuracy": tf.metrics.accuracy(
                labels=labels,
                predictions=predictions["class"])}
    return tf.estimator.EstimatorSpec(
        mode=mode,
        loss=loss,
        eval_metric_ops=eval_metric_ops)
    
#     config = tf.ConfigProto()
#     config.gpu_options.allow_growth=True
#     sess = tf.Session(config=config)
#     sess.run(tf.global_variables_initializer())
#     return sess.run(pool2, feed_dict =
#                     {input_data: features,
#                      input_
#                     labels: labels})



#print(cnn_4_cifar(train_data[0:2], train_label[0:2]))

# config = tf.ConfigProto()
# config.gpu_options.allow_growth=True
# sess = tf.Session(config=config)

# %%
###### estimator ######
config1 = tf.estimator.RunConfig()
config1 = config1.replace(log_step_count_steps = 1000, save_summary_steps = 1000)


cifar_classifier = tf.estimator.Estimator(
    model_fn = cnn_4_cifar,
    model_dir="./tmp/cifar_cnn_lrn17_model",
    config = config1
)

###### log ######

tensors_to_log = {"probabilities": "softmax_tensor"}
logging_hook = tf.train.LoggingTensorHook(
    tensors=tensors_to_log, every_n_iter=50)

###### training ######
# train_data_tf = tf.convert_to_tensor(
#     value = train_data,
#     dtype = tf.float32
# )
print(tf.shape(train_data.astype(np.float32)))

train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": train_data.astype(np.float32)},
    y=train_label,
    batch_size=100,
    num_epochs=None,
    shuffle=True)



eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": val_data.astype(np.float32)},
    y=val_label,
    num_epochs=1,
    shuffle=False)

for i in range(100):
    cifar_classifier.train(
        input_fn=train_input_fn,
        steps = 1000
    )
    cifar_classifier.evaluate(input_fn=eval_input_fn)


    # hooks = [logging_hook]
# Out:
# INFO:tensorflow:Using config: {'_model_dir': './tmp/cifar_cnn_lrn17_model', '_tf_random_seed': 1, '_save_summary_steps': 1000, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1000}
# Tensor("Shape:0", shape=(2,), dtype=int32)
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-58001
# INFO:tensorflow:Saving checkpoints for 58002 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:loss = 1.43509, step = 58002
# INFO:tensorflow:loss = 1.56446, step = 58102 (0.799 sec)
# INFO:tensorflow:loss = 1.59359, step = 58202 (0.756 sec)
# INFO:tensorflow:loss = 1.5056, step = 58302 (0.756 sec)
# INFO:tensorflow:loss = 1.36083, step = 58402 (0.757 sec)
# INFO:tensorflow:loss = 1.48865, step = 58502 (0.753 sec)
# INFO:tensorflow:loss = 1.35402, step = 58602 (0.753 sec)
# INFO:tensorflow:loss = 1.33256, step = 58702 (0.762 sec)
# INFO:tensorflow:loss = 1.4979, step = 58802 (0.758 sec)
# INFO:tensorflow:loss = 1.54891, step = 58902 (0.755 sec)
# INFO:tensorflow:Saving checkpoints for 59001 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.50693.
# INFO:tensorflow:Starting evaluation at 2018-02-11-22:44:49
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-59001
# INFO:tensorflow:Finished evaluation at 2018-02-11-22:44:50
# INFO:tensorflow:Saving dict for global step 59001: accuracy = 0.518, global_step = 59001, loss = 1.37496
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-59001
# INFO:tensorflow:Saving checkpoints for 59002 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:loss = 1.4288, step = 59002
# INFO:tensorflow:loss = 1.17625, step = 59102 (0.765 sec)
# INFO:tensorflow:loss = 1.54092, step = 59202 (0.755 sec)
# INFO:tensorflow:loss = 1.48911, step = 59302 (0.759 sec)
# INFO:tensorflow:loss = 1.58662, step = 59402 (0.756 sec)
# INFO:tensorflow:loss = 1.40846, step = 59502 (0.751 sec)
# INFO:tensorflow:loss = 1.22645, step = 59602 (0.751 sec)
# INFO:tensorflow:loss = 1.61784, step = 59702 (0.757 sec)
# INFO:tensorflow:loss = 1.18731, step = 59802 (0.751 sec)
# INFO:tensorflow:loss = 1.27977, step = 59902 (0.755 sec)
# INFO:tensorflow:Saving checkpoints for 60001 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.26621.
# INFO:tensorflow:Starting evaluation at 2018-02-11-22:44:58
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-60001
# INFO:tensorflow:Finished evaluation at 2018-02-11-22:44:58
# INFO:tensorflow:Saving dict for global step 60001: accuracy = 0.546, global_step = 60001, loss = 1.30232
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-60001
# INFO:tensorflow:Saving checkpoints for 60002 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:loss =
 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.0938.
# INFO:tensorflow:Starting evaluation at 2018-02-11-22:45:32
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-64001
# INFO:tensorflow:Finished evaluation at 2018-02-11-22:45:32
# INFO:tensorflow:Saving dict for global step 64001: accuracy = 0.553, global_step = 64001, loss = 1.22281
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-64001
# INFO:tensorflow:Saving checkpoints for 64002 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:loss = 1.1771, step = 64002
# INFO:tensorflow:loss = 1.17237, step = 64102 (0.789 sec)
# INFO:tensorflow:loss = 1.25131, step = 64202 (0.772 sec)
# INFO:tensorflow:loss = 1.22565, step = 64302 (0.774 sec)
# INFO:tensorflow:loss = 1.16879, step = 64402 (0.776 sec)
# INFO:tensorflow:loss = 1.19063, step = 64502 (0.777 sec)
# INFO:tensorflow:loss = 1.11729, step = 64602 (0.778 sec)
# INFO:tensorflow:loss = 1.272, step = 64702 (0.770 sec)
# INFO:tensorflow:loss = 1.02816, step = 64802 (0.774 sec)
# INFO:tensorflow:loss = 1.07523, step = 64902 (0.782 sec)
# INFO:tensorflow:Saving checkpoints for 65001 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.15619.
# INFO:tensorflow:Starting evaluation at 2018-02-11-22:45:40
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-65001
# INFO:tensorflow:Finished evaluation at 2018-02-11-22:45:40
# INFO:tensorflow:Saving dict for global step 65001: accuracy = 0.556, global_step = 65001, loss = 1.21704
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-65001
# INFO:tensorflow:Saving checkpoints for 65002 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:loss = 1.26844, step = 65002
# INFO:tensorflow:loss = 1.14716, step = 65102 (0.784 sec)
# INFO:tensorflow:loss = 1.10073, step = 65202 (0.766 sec)
# INFO:tensorflow:loss = 1.02192, step = 65302 (0.771 sec)
# INFO:tensorflow:loss = 1.37298, step = 65402 (0.769 sec)
# INFO:tensorflow:loss = 1.05774, step = 65502 (0.769 sec)
# INFO:tensorflow:loss = 1.05308, step = 65602 (0.766 sec)
# INFO:tensorflow:loss = 1.03778, step = 65702 (0.772 sec)
# INFO:tensorflow:loss = 1.10043, step = 65802 (0.769 sec)
# INFO:tensorflow:loss = 1.1568, step = 65902 (0.771 sec)
# INFO:tensorflow:Saving checkpoints for 66001 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.1403.
# INFO:tensorflow:Starting evaluation at 2018-02-11-22:45:48
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-66001
# INFO:tensorflow:Finished evaluation at 2018-02-11-22:45:49
# INFO:tensorflow:Saving dict for global step 66001: accuracy = 0.571, global_step = 66001, loss = 1.19602
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-66001
# INFO:tensorflow:Saving checkpoints for 66002 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:loss = 1.04649, step = 66002
# INFO:tensorflow:loss = 1.34978, step = 66102 (0.786 sec)
# INFO:tensorflow:loss = 1.15015, step = 66202 (0.778 sec)
# INFO:tensorflow:loss = 1.21872, step = 66302 (0.768 sec)
# INFO:tensorflow:loss = 1.22969, step = 66402 (0.774 sec)
# INFO:tensorflow:loss = 0.946457, step = 66502 (0.772 sec)
# INFO:tensorflow:loss = 1.14832, step = 66602 (0.772 sec)
# INFO:tensorflow:loss = 1.15485, step = 66702 (0.771 sec)
# INFO:tensorflow:loss = 1.12388, step = 66802 (0.772 sec)
# INFO:tensorflow:loss = 1.28701, step = 66902 (0.772 sec)
# INFO:tensorflow:Saving checkpoints for 67001 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.22978.
# INFO:tensorflow:Starting evaluation at 2018-02-11-22:45:57
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-67001
# INFO:tensorflow:Finished evaluation at 2018-02-11-22:45:57
# INFO:tensorflow:Saving dict for global step 67001: accuracy = 0.58, global_step = 67001, loss = 1.15769
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-67001
# INFO:tensorflow:Saving checkpoints for 67002 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:loss =
 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.784066.
# INFO:tensorflow:Starting evaluation at 2018-02-11-22:48:28
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-85001
# INFO:tensorflow:Finished evaluation at 2018-02-11-22:48:29
# INFO:tensorflow:Saving dict for global step 85001: accuracy = 0.599, global_step = 85001, loss = 1.17132
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-85001
# INFO:tensorflow:Saving checkpoints for 85002 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:loss = 0.668125, step = 85002
# INFO:tensorflow:loss = 1.0307, step = 85102 (0.790 sec)
# INFO:tensorflow:loss = 0.971111, step = 85202 (0.780 sec)
# INFO:tensorflow:loss = 0.975207, step = 85302 (0.778 sec)
# INFO:tensorflow:loss = 0.821562, step = 85402 (0.774 sec)
# INFO:tensorflow:loss = 0.771471, step = 85502 (0.776 sec)
# INFO:tensorflow:loss = 0.798747, step = 85602 (0.776 sec)
# INFO:tensorflow:loss = 0.864047, step = 85702 (0.787 sec)
# INFO:tensorflow:loss = 0.881984, step = 85802 (0.773 sec)
# INFO:tensorflow:loss = 0.864146, step = 85902 (0.775 sec)
# INFO:tensorflow:Saving checkpoints for 86001 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.558922.
# INFO:tensorflow:Starting evaluation at 2018-02-11-22:48:37
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-86001
# INFO:tensorflow:Finished evaluation at 2018-02-11-22:48:37
# INFO:tensorflow:Saving dict for global step 86001: accuracy = 0.588, global_step = 86001, loss = 1.20986
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-86001
# INFO:tensorflow:Saving checkpoints for 86002 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:loss = 0.828261, step = 86002
# INFO:tensorflow:loss = 0.819618, step = 86102 (0.787 sec)
# INFO:tensorflow:loss = 0.79362, step = 86202 (0.769 sec)
# INFO:tensorflow:loss = 0.701063, step = 86302 (0.768 sec)
# INFO:tensorflow:loss = 0.831992, step = 86402 (0.774 sec)
# INFO:tensorflow:loss = 0.822505, step = 86502 (0.771 sec)
# INFO:tensorflow:loss = 0.736081, step = 86602 (0.772 sec)
# INFO:tensorflow:loss = 0.754932, step = 86702 (0.767 sec)
# INFO:tensorflow:loss = 0.720886, step = 86802 (0.774 sec)
# INFO:tensorflow:loss = 0.964294, step = 86902 (0.771 sec)
# INFO:tensorflow:Saving checkpoints for 87001 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.893799.
# INFO:tensorflow:Starting evaluation at 2018-02-11-22:48:45
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-87001
# INFO:tensorflow:Finished evaluation at 2018-02-11-22:48:45
# INFO:tensorflow:Saving dict for global step 87001: accuracy = 0.595, global_step = 87001, loss = 1.18066
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-87001
# INFO:tensorflow:Saving checkpoints for 87002 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:loss = 0.681507, step = 87002
# INFO:tensorflow:loss = 0.683752, step = 87102 (0.787 sec)
# INFO:tensorflow:loss = 0.625809, step = 87202 (0.767 sec)
# INFO:tensorflow:loss = 0.847894, step = 87302 (0.772 sec)
# INFO:tensorflow:loss = 0.738011, step = 87402 (0.776 sec)
# INFO:tensorflow:loss = 0.767423, step = 87502 (0.775 sec)
# INFO:tensorflow:loss = 0.773109, step = 87602 (0.768 sec)
# INFO:tensorflow:loss = 0.719536, step = 87702 (0.772 sec)
# INFO:tensorflow:loss = 0.795913, step = 87802 (0.769 sec)
# INFO:tensorflow:loss = 0.884162, step = 87902 (0.778 sec)
# INFO:tensorflow:Saving checkpoints for 88001 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.743496.
# INFO:tensorflow:Starting evaluation at 2018-02-11-22:48:54
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-88001
# INFO:tensorflow:Finished evaluation at 2018-02-11-22:48:54
# INFO:tensorflow:Saving dict for global step 88001: accuracy = 0.597, global_step = 88001, loss = 1.1759
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-88001
# INFO:tensorflow:Saving checkpoints for 88002 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:loss =
 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.654244.
# INFO:tensorflow:Starting evaluation at 2018-02-11-22:49:27
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-92001
# INFO:tensorflow:Finished evaluation at 2018-02-11-22:49:28
# INFO:tensorflow:Saving dict for global step 92001: accuracy = 0.575, global_step = 92001, loss = 1.31699
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-92001
# INFO:tensorflow:Saving checkpoints for 92002 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:loss = 0.786112, step = 92002
# INFO:tensorflow:loss = 0.563606, step = 92102 (0.788 sec)
# INFO:tensorflow:loss = 0.717142, step = 92202 (0.770 sec)
# INFO:tensorflow:loss = 0.780663, step = 92302 (0.775 sec)
# INFO:tensorflow:loss = 0.705108, step = 92402 (0.784 sec)
# INFO:tensorflow:loss = 0.665002, step = 92502 (0.780 sec)
# INFO:tensorflow:loss = 0.669385, step = 92602 (0.775 sec)
# INFO:tensorflow:loss = 0.674508, step = 92702 (0.774 sec)
# INFO:tensorflow:loss = 0.785299, step = 92802 (0.773 sec)
# INFO:tensorflow:loss = 0.868407, step = 92902 (0.783 sec)
# INFO:tensorflow:Saving checkpoints for 93001 into ./tmp/cifar_cnn_lrn17_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.623414.
# INFO:tensorflow:Starting evaluation at 2018-02-11-22:49:36
# INFO:tensorflow:Restoring parameters from ./tmp/cifar_cnn_lrn17_model/model.ckpt-93001
# INFO:tensorflow:Finished evaluation at 2018-02-11-22:49:36
# INFO:tensorflow:Saving dict for global step 93001: accuracy = 0.588, global_step = 93001, loss = 1.25405
# ------------------------------------------------------------------
# KeyboardInterrupt                Traceback (most recent call last)
# <ipython-input-6-81ab39bab26f> in <module>()
#      41     cifar_classifier.train(
#      42         input_fn=train_input_fn,
# ---> 43         steps = 1000
#      44     )
#      45     cifar_classifier.evaluate(input_fn=eval_input_fn)
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps)
#     239       hooks.append(training.StopAtStepHook(steps, max_steps))
#     240
# --> 241     loss = self._train_model(input_fn=input_fn, hooks=hooks)
#     242     logging.info('Loss for final step: %s.', loss)
#     243     return self
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _train_model(self, input_fn, hooks)
#     628           input_fn, model_fn_lib.ModeKeys.TRAIN)
#     629       estimator_spec = self._call_model_fn(features, labels,
# --> 630                                            model_fn_lib.ModeKeys.TRAIN)
#     631       ops.add_to_collection(ops.GraphKeys.LOSSES, estimator_spec.loss)
#     632       all_hooks.extend(hooks)
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode)
#     613     if 'config' in model_fn_args:
#     614       kwargs['config'] = self.config
# --> 615     model_fn_results = self._model_fn(features=features, **kwargs)
#     616
#     617     if not isinstance(model_fn_results, model_fn_lib.EstimatorSpec):
#
# <ipython-input-5-f75853f2cdbc> in cnn_4_cifar(features, labels, mode)
#     129         inputs = dense2,
#     130         rate = 0.1,
# --> 131         training = (mode == tf.estimator.ModeKeys.TRAIN)
#     132     )
#     133     ###### logits layer ######
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/layers/core.py in dropout(inputs, rate, noise_shape, seed, training, name)
#     300   """
#     301   layer = Dropout(rate, noise_shape=noise_shape, seed=seed, name=name)
# --> 302   return layer.apply(inputs, training=training)
#     303
#     304
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/layers/base.py in apply(self, inputs, *args, **kwargs)
#     501       Output tensor(s).
#     502     """
# --> 503     return self.__call__(inputs, *args, **kwargs)
#     504
#     505   def _assert_input_compatibility(self, inputs):
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/layers/base.py in __call__(self, inputs, *args, **kwargs)
#     448         # Check input assumptions set after layer building, e.g. input shape.
#     449         self._assert_input_compatibility(inputs)
# --> 450         outputs = self.call(inputs, *args, **kwargs)
#     451
#     452         # Apply activity regularization.
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/layers/core.py in call(self, inputs, training)
#     262     return utils.smart_cond(training,
#     263                             dropped_inputs,
# --> 264                             lambda: array_ops.identity(inputs))
#     265
#     266
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/layers/utils.py in smart_cond(pred, fn1, fn2, name)
#     209   if pred_value is not None:
#     210     if pred_value:
# --> 211       return fn1()
#     212     else:
#     213       return fn2()
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/layers/core.py in dropped_inputs()
#     259       return nn.dropout(inputs, 1  - self.rate,
#     260                         noise_shape=self._get_noise_shape(inputs),
# --> 261                         seed=self.seed)
#     262     return utils.smart_cond(training,
#     263                             dropped_inputs,
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in dropout(x, keep_prob, noise_shape, seed, name)
#    1913     random_tensor += random_ops.random_uniform(noise_shape,
#    1914                                                seed=seed,
# -> 1915                                                dtype=x.dtype)
#    1916     # 0. if [keep_prob, 1.0) and 1. if [1.0, 1.0 + keep_prob)
#    1917     binary_tensor = math_ops.floor(random_tensor)
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/ops/random_ops.py in random_uniform(shape, minval, maxval, dtype, seed, name)
#     239       rnd = gen_random_ops._random_uniform(
#     240           shape, dtype, seed=seed1, seed2=seed2)
# --> 241       return math_ops.add(rnd * (maxval - minval), minval, name=name)
#     242
#     243
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#     863           else:
#     864             raise
# --> 865       return func(x, y, name=name)
#     866
#     867   def binary_op_wrapper_sparse(sp_x, y):
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py in _sub(x, y, name)
#    2627     A `Tensor`. Has the same type as `x`.
#    2628   """
# -> 2629   result = _op_def_lib.apply_op("Sub", x=x, y=y, name=name)
#    2630   return result
#    2631
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     765         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     766                          input_types=input_types, attrs=attr_protos,
# --> 767                          op_def=op_def)
#     768         if output_structure:
#     769           outputs = op.outputs
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2628     ret = Operation(node_def, self, inputs=inputs, output_types=dtypes,
#    2629                     control_inputs=control_inputs, input_types=input_types,
# -> 2630                     original_op=self._default_original_op, op_def=op_def)
#    2631     if compute_shapes:
#    2632       set_shapes_for_outputs(ret)
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1212     # assigning id to this op until all ops this could be dependent on are
#    1213     # created.
# -> 1214     self._id_value = self._graph._next_id()  # pylint: disable=protected-access
#    1215     self._recompute_node_def()
#    1216
#
# ~/anaconda3/envs/ht-dl-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _next_id(self)
#    2885     with self._lock:
#    2886       self._next_id_counter += 1
# -> 2887       return self._next_id_counter
#    2888
#    2889   @property
#
# KeyboardInterrupt:

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": val_data.astype(np.float32)},
    y=val_label,
    num_epochs=1,
    shuffle=False)
eval_results = cifar_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)

# %%
from cnn_jupyter_tensorboard import show_graph
tf.reset_default_graph()
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
with tf.Session(config=config) as sess:
    saver = tf.train.import_meta_graph(
        './tmp/cifar_cnn_lrn11_model/model.ckpt-50500.meta')
    graph = tf.get_default_graph()
    show_graph(graph)
# Out:
#         <iframe seamless style="width:1000px;height:620px;border:0" srcdoc="
#         <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/polymer/0.3.3/platform.js&quot;></script>
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.3778533819731559&quot;).pbtxt = 'node {\n  name: &quot;global_step/Initializer/zeros&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@global_step&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT64\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT64\n        tensor_shape {\n        }\n        int64_val: 0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;global_step&quot;\n  op: &quot;VariableV2&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@global_step&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT64\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;global_step/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;global_step&quot;\n  input: &quot;global_step/Initializer/zeros&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT64\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@global_step&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;use_locking&quot;\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: &quot;validate_shape&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;global_step/read&quot;\n  op: &quot;Identity&quot;\n  input: &quot;global_step&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT64\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@global_step&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;enqueue_input/random_shuffle_queue&quot;\n  op: &quot;RandomShuffleQueueV2&quot;\n  device: &quot;/device:CPU:0&quot;\n  attr {\n    key: &quot;capacity&quot;\n    value {\n      i: 1000\n    }\n  }\n  attr {\n    key: &quot;component_types&quot;\n    value {\n      list {\n        type: DT_INT64\n        type: DT_FLOAT\n        type: DT_INT64\n      }\n    }\n  }\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;min_after_dequeue&quot;\n    value {\n      i: 250\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 1\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 4\n    }\n  }\n  attr {\n    key: &quot;shapes&quot;\n    value {\n      list {\n        shape {\n        }\n        shape {\n          dim {\n            size: 3072\n          }\n        }\n        shape {\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;enqueue_input/Placeholder&quot;\n  op: &quot;Placeholder&quot;\n  device: &quot;/device:CPU:0&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT64\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        unknown_rank: true\n      }\n    }\n  }\n}\nnode {\n  name: &quot;enqueue_input/Placeholder_1&quot;\n  op: &quot;Placeholder&quot;\n  device: &quot;/device:CPU:0&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        unknown_rank: true\n      }\n    }\n  }\n}\nnode {\n  name: &quot;enqueue_input/Placeholder_2&quot;\n  op: &quot;Placeholder&quot;\n  device: &quot;/device:CPU:0&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT64\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        unknown_rank: true\n      }\n    }\n  }\n}\nnode {\n  ...
